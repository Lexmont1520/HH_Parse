# %% [markdown]
# ###### Ver.3
# 1. Добавлена статистика с графиками
# 2. Добавлено дополнительное поле в парсере и в SQL: requirement
# 3. Добавлена функция парсинга ключевых навыков skills2sql из вакансий и дополнительное поле в SQL: skills
# 4. Расчет Top20 навыков и Top20 компаний-работодателей c построением графика
# 5. Добавлен парсинг по 2-м городам, Моска и Санкт-Петербург
#
# ###### Ver.2
# 1. Добавлена функция <b>parsing_salary()</b> для парсинга поля salary, которая возвращает salary_min, salary_max.
# 2. Пересчитывает поля salary_min, salary_max в зависимости от текущего курса USD и EUR. Т.е все зарплаты приведены к одной валюте - руб.

# %% [markdown]
# ### 1. Back End. Парсинг HTML сохранение данных в SQL

# %%
import requests as r
from bs4 import BeautifulSoup as bs
import sqlite3
import statistics as st # Модуль статистики
import matplotlib.pyplot as plt # Модуль построения графиков, гистограмм
import numpy as np
from IPython.display import set_matplotlib_formats

# %%
# Переменные
headers = {'user-agent': "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/605.1.15 \
           (KHTML, like Gecko) Version/12.1 Safari/605.1.15"}
# Формирование url вида:
# https://hh.ru/search/vacancy?search_period=30&clusters=true&area=1&text=Python&enable_snippets=true&page=0
str_search = 'Python'
url = 'https://hh.ru/search/vacancy'
payload = {'search_period':30,  
           'area':[1,2], # 1 - Москва, 2 - Питер
           'text': str_search, 
           'page':0}
    
page_count = 100 # Кол-во обрабатываемых страниц с сайта hh.ru
db_file = 'hh.db' # Имя файла с Data Base
sql_create_table_hh = """ CREATE TABLE IF NOT EXISTS hh (
                                    id integer PRIMARY KEY,
                                    title text, 
                                    href test, 
                                    company text, 
                                    address text, 
                                    responsibility text,
                                    requirement text,
                                    salary_min integer,
                                    salary_max integer,
                                    skills text
                                ); """
currency_usd = 64.42 # Курс USD
currency_eur = 71.84 # Курс EUR

# %%
############### Функции для работы с sqlite #########################################
def create_connection(db_file):
    """ 
        create a database connection to the SQLite database specified by db_file
        :param db_file: database file
        :return: Connection object or None
    """
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except Error as e:
        print(e)
 
    return None

def create_table(conn, create_table_sql):
    """ 
        create a table from the create_table_sql statement
        :param conn: Connection object
        :param create_table_sql: a CREATE TABLE statement
        :return:
    """
    try:
        cur = conn.cursor()
        cur.execute(create_table_sql)
    except Error as e:
        print(e)

def insert_data(conn, data):
    """
        Create a new data into the hh table
        :param conn: Connection object
        :param data:
        :return: id
    """
    sql = ''' INSERT INTO hh(title, href, company, address, responsibility, requirement, salary_min, \
                                salary_max, skills) VALUES(?,?,?,?,?,?,?,?,?) '''
    cur = conn.cursor()
    cur.execute(sql, data)
    return cur.lastrowid

def select_data(conn, sql_query):
    """
        Select data from DB
        :param conn: Connection object
        :param sql_query: sql query
        :return: id
    """
    cur = conn.cursor()
    cur.execute(sql_query)
    return cur.fetchall()


def drop_table(conn, table_name):
    """ 
        drop table
        :param conn: Connection object
        :param table_name: table name
        :return:
    """
    sql = """ DROP TABLE IF EXISTS %s """ % table_name
    try:
        cur = conn.cursor()
        cur.execute(sql)
    except Error as e:
        print(e)

#################################################################################

# %%
#################### Функция парсинга HTML в SQL ################################
def html2sql(url, payload, headers, conn):
    request = r.get(url, params=payload, headers=headers)
    print("Request URL:\n{}".format(request.url))
    if request.status_code == 200:
        soup = bs(request.content, 'html.parser')
        divs = soup.find_all("div", attrs= {"data-qa":"vacancy-serp__vacancy"})
        
        for div in divs:
            title = div.find("a", attrs = {"data-qa":"vacancy-serp__vacancy-title"}).text
            href = div.find("a", attrs = {"data-qa":"vacancy-serp__vacancy-title"})['href']
            try:
                company = div.find('a', attrs = {"data-qa":"vacancy-serp__vacancy-employer"}).text
            except:
                company = 'Unknown'
            address = div.find('span', attrs = {"data-qa":"vacancy-serp__vacancy-address"}).text
            responsibility = div.find('div', attrs = {"data-qa":"vacancy-serp__vacancy_snippet_responsibility"}).text
            requirement = div.find('div', attrs = {"data-qa":"vacancy-serp__vacancy_snippet_requirement"}).text
            try:
                salary = div.find("div", attrs = {"data-qa":"vacancy-serp__vacancy-compensation"}).text.replace('\xa0', '')
                salary_min, salary_max = parsing_salary(salary)
            except AttributeError:
                salary_min, salary_max = '0','0'
                
            # Парсинг Ключевых навыков
            skills = skills2sql(href, headers)
    
            # Insert data to SQL:
            data = (title, href, company, address, responsibility, requirement, salary_min, salary_max, skills)
            insert_data(conn, data)
        
        print('Done\n')
    else:
        print("Error!!! Status code: ", request.status_code)


#################### Функция парсинга навыков (skill) из вакансий ################################
def skills2sql(vacancy_url, headers):
    request = r.get(vacancy_url, headers=headers)
    #print("Request URL:\n{}".format(request.url))
    if request.status_code == 200:
        soup = bs(request.content, 'html.parser')
        divs = soup.find_all("span", attrs= {"data-qa":"skills-element"})
        skills = []
        for div in divs:
            skill = div.find("span", attrs = {"data-qa":"bloko-tag__text"}).text.lower()
            skills.append(skill)
        if len(skills) == 0:
            skills = ['No skills']
        skills = ', '.join(skills)
        return skills
    else:
        print("Error!!! Status code: ", request.status_code)


???#################### Функция парсинга salary ################################
def parsing_salary(salary):
    salary_dig = salary.lower().replace('от ', '').replace('до ', '0 ').replace('-', ' ').split()
    if len(salary_dig) == 2:
        result=[salary_dig[0],'0',salary_dig[1]]
        if result[2] == 'eur':
            result = [float(result[0]) * currency_eur, float(result[1]) * currency_eur]
        elif result[2] == 'usd':
            result = [float(result[0]) * currency_usd, float(result[1]) * currency_usd]
        else:
            result = [float(result[0]), float(result[1])]
        
    elif len(salary_dig) == 3:
        result=salary_dig
        if result[2] == 'eur':
            result = [float(result[0]) * currency_eur, float(result[1]) * currency_eur]
        elif result[2] == 'usd':
            result = [float(result[0]) * currency_usd, float(result[1]) * currency_usd]
        else:
            result = [float(result[0]), float(result[1])]
    else:
        print('Error parsing salary field!!!')
    
    return result

# %%
################################  Main program ###############################

# Create a database connection
conn = create_connection(db_file)
if conn is not None:
    # create hh table
    create_table(conn, sql_create_table_hh)
else:
    print("Error! cannot create the database connection.")

# Parsing HTML to DB
with conn:
    for page in range(page_count): # Go to page
        payload['page'] = page
        html2sql(url, payload, headers, conn)

##############################################################################
# Out:
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=0
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=1
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=2
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=3
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=4
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=5
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=6
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=7
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=8
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=9
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=10
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=11
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=12
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=13
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=14
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=15
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=16
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=17
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=18
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=19
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=20
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=21
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=22
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=23
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=24
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=25
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=26
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=27
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=28
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=29
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=30
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=31
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=32
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=33
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=34
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=35
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=36
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=37
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=38
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=39
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=40
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=41
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=42
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=43
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=44
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=45
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=46
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=47
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=48
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=49
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=50
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=51
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=52
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=53
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=54
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=55
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=56
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=57
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=58
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=59
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=60
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=61
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=62
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=63
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=64
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=65
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=66
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=67
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=68
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=69
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=70
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=71
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=72
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=73
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=74
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=75
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=76
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=77
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=78
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=79
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=80
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=81
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=82
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=83
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=84
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=85
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=86
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=87
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=88
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=89
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=90
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=91
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=92
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=93
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=94
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=95
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=96
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=97
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=98
# Done
#
# Request URL:
# https://hh.ru/search/vacancy?search_period=30&area=1&area=2&text=Python&page=99
# Done

# %% [markdown]
# #### Примеры выборок из DB

# %%
conn = create_connection(db_file)

# %%
select_data(conn, ''' SELECT address FROM hh WHERE address LIKE '%Москва%' LIMIT 0,5 ''' )
# Out:
# [('Москва, Парк культуры',),
#  ('Москва, Чертановская',),
#  ('Москва',),
#  ('Москва, Площадь Революции и еще 1 ',),
#  ('Москва',)]

# %%
select_data(conn, ''' SELECT * FROM hh WHERE title LIKE '%Python%' LIMIT 0,3 ''' )
# Out:
# [(1,
#   'Python Developer',
#   'https://hh.ru/vacancy/31550822?query=Python',
#   ' LLC ICONIC',
#   'Москва, Парк культуры',
#   'Разработка web сервисов на протоколе GraphQL. Разработка микросервисов. Интеграции с blockchain нодами.',
#   'Опыт коммерческой разработки от 4х лет. Опыт разработки на Python 3 не менее 3 лет (желательно на версии выше...',
#   170000,
#   250000,
#   'No skills'),
#  (2,
#   'Разработчик Python',
#   'https://hh.ru/vacancy/31624245?query=Python',
#   'ОАО Оператор систем пенсионного обеспечения и страхования',
#   'Москва, Чертановская',
#   'Проектирование и разработка backend - сервисов на языке Python. Написание unit-тестов. - понимание смежных областей разработки ПО (управление, анализ требований, проектирование...',
#   'Отличные знания Python 3. Владение общими вопросами программирования: шаблоны проектирования, структуры данных, алгоритмы. Опыт использования систем контроля версий. ',
#   160000,
#   200000,
#   'python'),
#  (3,
#   'Python разработчик \u200d\u200d',
#   'https://hh.ru/vacancy/30934505?query=Python',
#   'ООО АппФоллоу',
#   'Санкт-Петербург',
#   'Парсинг и хранение данных: (ключевые слова, позиции приложений в Top чартах, фичеринг) в App Store и Google Play, Mac Store...',
#   'Python-разработчик, найдись! Уверенное владение Python, MySQL, MongoDB, Redis. Владение WSGI frameworks, Aiohttp или Asyncio производных. Понимание распределенных/параллельных вычислений. ',
#   70000,
#   140000,
#   'linux, docker, mysql, aiohttp, redis, django framework, mongodb, asyncio, ubuntu server, python')]

# %%
select_data(conn, ''' SELECT title, salary_min, salary_max, href \
                            FROM hh WHERE salary_min >= '300000' ''' )
# Out:
# [('Data Engineering Team Lead (Python / C++)',
#   300000,
#   400000,
#   'https://hh.ru/vacancy/31522998?query=Python'),
#  ('Quantitative Researcher',
#   300000,
#   0,
#   'https://hh.ru/vacancy/29014173?query=Python'),
#  ('Lead Ops engineer',
#   300000,
#   350000,
#   'https://hh.ru/vacancy/31353144?query=Python')]

# %%
select_data(conn, ''' SELECT COUNT(*) FROM hh WHERE salary_min = 150000 ''' )
# Out:
# [(52,)]

# %%
select_data(conn, ''' SELECT COUNT(*) FROM hh ''' )
# Out:
# [(1979,)]

# %%
select_data(conn, ''' SELECT * FROM hh WHERE company = 'Unknown' ''' )
# Out:
# [(615,
#   'Portfolio Analyst',
#   'https://hh.ru/vacancy/31637018?query=Python',
#   'Unknown',
#   'Москва',
#   'Portfolio monitoring and strategic planning (Fixed Income). - Search for new investment ideas and strategies. - Provide assistance in the production of...',
#   'Good understanding of corporate finance/macroeconomics/accounting. - Strong Excel, Power Point skills (VBA, Python as advantage). - Knowledge of Bloomberg/Reuters...',
#   0,
#   0,
#   'портфельные риски, vba, bloomberg/reuters'),
#  (1154,
#   'Программист Full-stack (JavaScript/TypeScript, С#)',
#   'https://hh.ru/vacancy/29123042?query=Python',
#   'Unknown',
#   'Москва',
#   'Экспертные «legal tech» системы. Поддержка аналитики юридических материалов и правовых ситуаций в реальном масштабе времени, наглядное отображение материала, инструменты для...',
#   'Используемые платформы и инструменты: Платформы: Windows, Linux, Docker/Kubernetes. Языки: С#, С++ (Windows-приложения), HTML5/CSS3, JavaScript, TypeScript...',
#   140000,
#   175000,
#   'No skills'),
#  (1296,
#   'Реверс-инженер',
#   'https://hh.ru/vacancy/31226074?query=Python',
#   'Unknown',
#   'Санкт-Петербург',
#   '4. Написание небольших програм и сценариев, в основном на python. 5. Работа с эмулятором firmadyne. 6. Разбор прошивок устройств, загрузчиками...',
#   '6. Уверенное знание С, Python, bash. 7. Понимание работы и техник эксплуатирования уязвимостей ПО. 8. Понимание работы сетей, фаерволов. ',
#   100000,
#   200000,
#   'No skills')]

# %%
# Удаление таблицы hh из DB
#drop_table(conn, 'hh')

# %% [markdown]
# ### 2. Анализ данных, статистика

# %%
def histogram(data1, data2, out_file="histogram.png", label1="", label2="", cumulative=False, x_label = "", y_label = "", 
              title = "", color1 = 'green', color2 = 'blue'):
    set_matplotlib_formats('retina') # Для retina дисплеев. Что бы графики были четкие.
    #plt.xkcd() # Для отрисовки в стиле комиксов
    fig, ax = plt.subplots(figsize=(12, 5)) 
    ax.hist(data1, bins='sturges', cumulative = cumulative, color = color1, alpha=0.5,
            edgecolor='black', linewidth=1, align='right', label = label1)
    ax.hist(data2, bins='sturges', cumulative = cumulative, color = color2, alpha=0.5,
            edgecolor='black', linewidth=1, align='right', label = label2)
    ax.set_ylabel(y_label)
    ax.set_xlabel(x_label)
    ax.set_title(title)
    ax.grid(color='grey', linestyle=':', linewidth=1) # Сетка
    ax.legend(loc='best', frameon=False)
    fig.savefig(out_file)   # save the figure to file

# %%
# Выборка из SQL
df_salary_min_msk = [i[0] for i in select_data(conn, ''' SELECT salary_min FROM hh \
                                                WHERE address LIKE '%Москва%' AND salary_min > 0 ''' )]
df_salary_max_msk = [i[0] for i in select_data(conn, ''' SELECT salary_max FROM hh \
                                                WHERE address LIKE '%Москва%' AND salary_max > 0 ''' )]
df_salary_min_spb = [i[0] for i in select_data(conn, ''' SELECT salary_min FROM hh \
                                                WHERE address LIKE '%Санкт-Петербург%' AND salary_min > 0 ''' )]
df_salary_max_spb = [i[0] for i in select_data(conn, ''' SELECT salary_max FROM hh \
                                                WHERE address LIKE '%Санкт-Петербург%' AND salary_max > 0 ''' )]

# %%
print('Кол-во вакансий для анализа с зарплатами: ',
      select_data(conn, ''' SELECT COUNT(*) FROM hh WHERE salary_min > 0 or salary_max > 0 ''' ))
# Out:
# Кол-во вакансий для анализа с зарплатами:  [(521,)]

# %% [markdown]
# #### Среднее

# %%
print('Средняя минимальная зарплата Москва: {:.2f} руб.'.format(st.mean(df_salary_min_msk)))
print('Средняя максимальная зарплата Москва: {:.2f} руб.'.format(st.mean(df_salary_max_msk)))
print()
print('Средняя минимальная зарплата Санкт-Петербург: {:.2f} руб.'.format(st.mean(df_salary_min_spb)))
print('Средняя максимальная зарплата Санкт-Петербург: {:.2f} руб.'.format(st.mean(df_salary_max_spb)))
# Out:
# Средняя минимальная зарплата Москва: 120364.52 руб.
# Средняя максимальная зарплата Москва: 164001.25 руб.
#
# Средняя минимальная зарплата Санкт-Петербург: 102721.69 руб.
# Средняя максимальная зарплата Санкт-Петербург: 146996.76 руб.

# %% [markdown]
# #### Медиана

# %%
print('Медиана по минимальным зарплатам Москва: {:.2f} руб.'.format(st.median(df_salary_min_msk)))
print('Медиана по максимальным зарплатам Москва: {:.2f} руб.'.format(st.median(df_salary_max_msk)))
print()
print('Медиана по минимальным зарплатам Санкт-Петербург: {:.2f} руб.'.format(st.median(df_salary_min_spb)))
print('Медиана по максимальным зарплатам Санкт-Петербург: {:.2f} руб.'.format(st.median(df_salary_max_spb)))
# Out:
# Медиана по минимальным зарплатам Москва: 120000.00 руб.
# Медиана по максимальным зарплатам Москва: 150000.00 руб.
#
# Медиана по минимальным зарплатам Санкт-Петербург: 100000.00 руб.
# Медиана по максимальным зарплатам Санкт-Петербург: 130000.00 руб.

# %% [markdown]
# #### Максимумы и минимумы

# %%
print('Минимальная зарплата Москва: {:.2f} руб.'.format(min(df_salary_min_msk)))
print('Максимальная зарплата Москва: {:.2f} руб.'.format(max(df_salary_max_msk)))
print()
print('Минимальная зарплата Санкт-Петербург: {:.2f} руб.'.format(min(df_salary_min_spb)))
print('Максимальная зарплата Санкт-Петербург: {:.2f} руб.'.format(max(df_salary_max_spb)))
# Out:
# Минимальная зарплата Москва: 20000.00 руб.
# Максимальная зарплата Москва: 400000.00 руб.
#
# Минимальная зарплата Санкт-Петербург: 15000.00 руб.
# Максимальная зарплата Санкт-Петербург: 386520.00 руб.

# %% [markdown]
# #### Гистограмма распределения зарплат

# %%
histogram(df_salary_min_msk, df_salary_min_spb, out_file='gist_salary_min.png', label1="MSK", label2="SPB",
          x_label = "Зарплата (руб)", y_label = "Частота", title = "Гистограмма распределения ЗП (min)")

# %%
histogram(df_salary_max_msk, df_salary_max_spb, out_file='gist_salary_max.png', label1="MSK", label2="SPB", 
          x_label = "Зарплата (руб)", y_label = "Частота", title = "Гистограмма распределения ЗП (max)", 
          color1 = '#8314cc', color2 = '#faee05')

# %% [markdown]
# ### 3. Top20 навыков

# %%
# Функция рисования горизонтальной гистограммы
def horizontal_barplot(data, x_label="", y_label="", title="", out_file="horizontal_bar.png", color = 'red'):
    set_matplotlib_formats('retina') # Для retina дисплеев. Что бы графики были четкие.
    #plt.xkcd() # Для отрисовки в стиле комиксов
    x_data, y_data = data[::,0], data[::,1]
    fig, ax = plt.subplots(figsize=(12, 6))
    # Draw bars, position them in the center of the tick mark on the x-axis
    ax.barh(x_data, y_data, color = color, align = 'center', edgecolor='black', linewidth=1, alpha=0.5)
    ax.set_ylabel(y_label)
    ax.set_xlabel(x_label)
    ax.set_title(title)
    ax.grid(color='grey', linestyle=':', linewidth=1) # Сетка
    fig.savefig(out_file)   # save the figure to file

# %%
# Функция подсчета TopN результатов
def top_resultat(data_list, top):
    '''
        data_list: list data
        top: number of top resultat
        return: sorted by value topN resultat and number of all results
    '''
    # Создаем словарь с нулевыми счетчиками
    d = dict.fromkeys(data_list, 0)
    # Считаем слова
    for count in data_list:
        d[count] += 1
    # Сортируем словарь по значению и по убыванию
    sorted_by_value = sorted(d.items(), key=lambda x: (x[1],x[0]), reverse=True)
    return sorted_by_value[0:top], len(sorted_by_value)

# %%
sql_query_skills = select_data(conn, ''' SELECT lower(skills) FROM hh WHERE skills !='No skills' ''' )
all_skills = ''.join([i[0]+', ' for i in sql_query_skills]).split(', ')[:-1]

# %%
sorted_by_value_20, sorted_by_value_full = top_resultat(all_skills, 20)

# %%
print('Top20 ключевых навыков:\n', sorted_by_value_20)
print('\nВсего ключевых навыков:', sorted_by_value_full)
# Out:
# Top20 ключевых навыков:
#  [('python', 617), ('linux', 258), ('sql', 203), ('postgresql', 150), ('git', 149), ('c++', 126), ('javascript', 116), ('django framework', 102), ('java', 96), ('mysql', 88), ('docker', 69), ('bash', 67), ('администрирование серверов linux', 51), ('html', 48), ('machine learning', 45), ('php', 43), ('ооп', 41), ('css', 41), ('c#', 41), ('тестирование', 39)]
#
# Всего ключевых навыков: 1284

# %%
# Сортировка списка в обратном порядке и преобразование в numpy массив для рисования гистограммы
sorted_by_value_revers_20 = np.array([i for i in reversed(sorted_by_value_20)])

# %%
horizontal_barplot(sorted_by_value_revers_20, x_label="Кол-во упоменаний в вакансиях", title='Top20 ключевых навыков',
                  out_file="Top20_skill.png")

# %% [markdown]
# ### 3. Top20 компаний-работодателей

# %%
sql_query_company = select_data(conn, ''' SELECT company FROM hh WHERE company !='Unknown' ''' )
all_company = ''.join([i[0].lstrip().rstrip().upper()+', ' for i in sql_query_company]).split(', ')[:-1]

# %%
company_sorted_by_value_20, company_sorted_by_value_full = top_resultat(all_company, 20)

# %%
print('Top20 компаний-работодателей:\n', company_sorted_by_value_20)
print('\nВсего компаний:', company_sorted_by_value_full)
# Out:
# Top20 компаний-работодателей:
#  [('СБЕРБАНК ДЛЯ ЭКСПЕРТОВ', 58), ('ЯНДЕКС', 42), ('ПАО МТС', 42), ('MAIL.RU GROUP', 25), ('С ОПЫТОМ РАБОТЫ', 17), ('ЛАБОРАТОРИЯ КАСПЕРСКОГО', 17), ('«РОСБАНК', 17), ('SOCIETE GENERALE GROUP»', 17), ('JETBRAINS', 16), ('КРОК', 15), ('X5 RETAIL GROUP', 15), ('SELECTEL', 15), ('ТИНЬКОФФ', 14), ('GROUP-IB', 14), ('DELL EMC', 14), ('АВИТО', 13), ('WARGAMING', 13), ('SAINT PETERSBURG (LESTA STUDIO)', 13), ('ЦИАН ГРУПП', 12), ('RAIFFEISENBANK', 12)]
#
# Всего компаний: 912

# %%
# Сортировка списка в обратном порядке и преобразование в numpy массив для рисования гистограммы
company_sorted_by_value_revers_20 = np.array([i for i in reversed(company_sorted_by_value_20)])

# %%
horizontal_barplot(company_sorted_by_value_revers_20, x_label="Кол-во вакансий", 
                   title='Top20 компаний-работодателей', out_file="Top20_company.png", color='blue')
